# %% [markdown]
# # GUESS MY WEIGHT
# A program to predict the weight from my health data
#
# ![guess_your_weight.gif](images/guess_your_weight.gif)

# %% [markdown]
# ## Overview
# Health and Wellness is a big business. Specifically, weight loss. We’re all trying because it’s very, very hard. I recently went on my own weight loss journey, losing about 50 lbs in roughly 18 months. Weighing myself every morning, I agonized over every tenth of a lb, recording it in an app on my phone. I realized that losing big chunks of weights starts with small, incremental progress on the scale. But I didn’t stop there. As a data nerd I thought, “let’s record every meal.” So I did that too. I wondered… given all this data I have, could I predict my weight? My watch and phone captures my exercise, sleep, eating, and so much more. There must be trends here. At a minimum, I should be able to predict whether my weight will go up or down from the previous day. So let’s do it.

# %% [markdown]
# ## Data Understanding
# I have much (and probably too much) of this data in my iphone and Apple Watch. It contains the weight information, workouts, heart rate, meals - broken down into subcategories (proteins, fats, etc). Most importantly is the weight. That will be the feature that I primarily use for classification.
#
# Because it’s my data, there’s more clarity about data entry methods. This is more subjective, than a controlled experiment with many participants. I know what data I was diligent about collecting so I should be able to scrub it appropriately. For instance, I didn’t record my fluids consistently - water, tea, coffee. Water consumption is a big part of this so I’ll have to be clear about the gaps in the data

# %% [markdown]
# ### Weigh-In Protocol
# The routine for entering the weigh-in was pretty basic. I recorded my weight on a 3rd party app, on the same bathroom scale, before I drank any fluids in the morning but after urination. Morning wiegh-in works well because it's a simple routine. More importantly though, you likely weight the least because you're dehydrated after a night of sleep.

# %% [markdown]
# ### Apple Health Data
# Besides the weigh-in and meal logging, all of the other data is generated by Apple's proprietary software. I can not speak to it's accuracy.

# %% [markdown]
# ### Meal Logging
# All of the meal logging was done to the best of my ability using judgements about serving sizes, volume, weights, etc. A kitchen scale was incorporated after January to the measurements would have improved in accuracy after that time. There are certain weeks where there is no data, especially around holidays and weekends. You'll have to do your best there.

# %% [markdown]
# ### Data scrubbing and transfer to Kaggle
# To execute this project, personal data was utilized from the iphone, scrubbed, and uploaded to Kaggle for storage. The file is approximately, 40 MB, so a public area where this is easily downloaded.
# #### Data Export from the Source
# To begin this project, I was able to Airdrop my health data from my Iphone to my personal labtop.
# #### Data Import to Jupyter Notebook
# So, we know we're dealing with an .xml file. We'll utilize the Element Tree (ET) function to bring into our notebook and then convert to pandas.

# %%
#import relevant functions
import pandas as pd
import xml.etree.ElementTree as ET

# %%
#extract data from the xml file and assign the root of the tree
tree = ET.parse("data_raw/export.xml")
root = tree.getroot()

# %%
#create pandas dataframe from list of health records
health_records = [x.attrib for x in root.iter('Record')]
record_data = pd.DataFrame(health_records)

# %%
#review dataframe to do high level inspection
record_data.head()
# Out:
#                                    type sourceName sourceVersion unit  \
# 0  HKQuantityTypeIdentifierDietaryWater    MyPlate             4   mL
# 1  HKQuantityTypeIdentifierDietaryWater    MyPlate             4   mL
# 2  HKQuantityTypeIdentifierDietaryWater    MyPlate             4   mL
# 3  HKQuantityTypeIdentifierDietaryWater    MyPlate             4   mL
# 4  HKQuantityTypeIdentifierDietaryWater    MyPlate             4   mL
#
#                 creationDate                  startDate  \
# 0  2022-06-01 13:20:27 -0500  2022-05-31 23:00:00 -0500
# 1  2022-07-11 09:43:30 -0500  2022-07-10 23:00:00 -0500
# 2  2022-07-13 20:57:54 -0500  2022-07-12 23:00:00 -0500
# 3  2022-07-14 12:42:54 -0500  2022-07-13 23:00:00 -0500
# 4  2022-07-16 18:11:29 -0500  2022-07-15 23:00:00 -0500
#
#                      endDate    value device
# 0  2022-05-31 23:00:00 -0500   354.84    NaN
# 1  2022-07-10 23:00:00 -0500  1064.52    NaN
# 2  2022-07-12 23:00:00 -0500  2129.04    NaN
# 3  2022-07-13 23:00:00 -0500   946.24    NaN
# 4  2022-07-15 23:00:00 -0500  2129.04    NaN

# %% [markdown]
# Looking at the above dataFrame, we can see the entries have come in 9 columns, exluding the index. It appears as though each entry contatins at least 3 date values, as well as information on the Source. Likely, the device information is blocked out. It looks we only need the `type` column, one `data` column, and the `value`. The sourceName, version, and additional timestamps are not needed.
#
# ### Data Scrubbing prior to Kaggle:
# As we mentioned above, we have some columns we'll delete. But prior to then, we need to focus out data on a date range that is relevant to our wieght loss. Let's search out the information related to Body Mass and see what we can find.

# %%
record_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2036997 entries, 0 to 2036996
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   type           object
#  1   sourceName     object
#  2   sourceVersion  object
#  3   unit           object
#  4   creationDate   object
#  5   startDate      object
#  6   endDate        object
#  7   value          object
#  8   device         object
# dtypes: object(9)
# memory usage: 139.9+ MB

# %% [markdown]
# So... We have many entries, apporxiamtely 2M. And there all generic string objects. There's a little scrubbing to do ahead of time. We'l go ahead and delete those 3 columns.

# %%
# drop SourceName, Source Type, and device.
records_df = record_data.drop(['sourceName', 'sourceVersion', 'device'], axis = 1)

# %%
import datetime as dt
#convert the time/date columns to datetime without time zone
records_df['creationDate'] = pd.to_datetime(records_df['creationDate']).dt.tz_localize(None)
records_df['startDate'] = pd.to_datetime(records_df['startDate']).dt.tz_localize(None)
records_df['endDate'] = pd.to_datetime(records_df['endDate']).dt.tz_localize(None)

#records_df['creationDate'] = records_df['creationDate'].dt.tz_localize(None)

#records_df['creationDate'].apply(lambda val: datetime.strptime(val, "%Y-%m-%d"))
# Out:
#                                                      type unit  \
# 0                    HKQuantityTypeIdentifierDietaryWater   mL
# 1                    HKQuantityTypeIdentifierDietaryWater   mL
# 2                    HKQuantityTypeIdentifierDietaryWater   mL
# 3                    HKQuantityTypeIdentifierDietaryWater   mL
# 4                    HKQuantityTypeIdentifierDietaryWater   mL
# ...                                                   ...  ...
# 2036992  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 2036993  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 2036994  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 2036995  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 2036996  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
#
#                creationDate           startDate             endDate    value
# 0       2022-06-01 13:20:27 2022-05-31 23:00:00 2022-05-31 23:00:00   354.84
# 1       2022-07-11 09:43:30 2022-07-10 23:00:00 2022-07-10 23:00:00  1064.52
# 2       2022-07-13 20:57:54 2022-07-12 23:00:00 2022-07-12 23:00:00  2129.04
# 3       2022-07-14 12:42:54 2022-07-13 23:00:00 2022-07-13 23:00:00   946.24
# 4       2022-07-16 18:11:29 2022-07-15 23:00:00 2022-07-15 23:00:00  2129.04
# ...                     ...                 ...                 ...      ...
# 2036992 2024-03-06 01:01:10 2024-03-06 01:00:08 2024-03-06 01:01:07  44.3289
# 2036993 2024-03-06 03:01:11 2024-03-06 03:00:09 2024-03-06 03:01:08  54.3759
# 2036994 2024-03-06 05:01:11 2024-03-06 05:00:09 2024-03-06 05:01:08    76.23
# 2036995 2024-03-06 07:01:22 2024-03-06 07:00:20 2024-03-06 07:01:20  45.6944
# 2036996 2024-03-06 09:39:13 2024-03-06 09:38:12 2024-03-06 09:39:11  10.3325
#
# [2036997 rows x 6 columns]

# %% [markdown]
# Now that we have converted the dates we can delete some of the files prior to the weight loss window we care about. I know from my weight loss app that I started the journey around July 24, 2023. So we can delete records prior to that date.

# %%
import datetime

cut_off = datetime.datetime(2023, 7, 23, 0, 0, 0, 0, tzinfo = None)

records_df = records_df.drop(records_df[(records_df['startDate'] < cut_off)].index, axis = 0)
#records_df.drop(records_df['startDate'] < cut_off, axis=0, inplace = True)
records_df
# Out:
#                                                      type unit  \
# 177                  HKQuantityTypeIdentifierDietaryWater   mL
# 230                  HKQuantityTypeIdentifierDietaryWater   mL
# 234                  HKQuantityTypeIdentifierDietaryWater   mL
# 235                  HKQuantityTypeIdentifierDietaryWater   mL
# 247                  HKQuantityTypeIdentifierDietaryWater   mL
# ...                                                   ...  ...
# 2036992  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 2036993  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 2036994  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 2036995  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
# 2036996  HKQuantityTypeIdentifierHeartRateVariabilitySDNN   ms
#
#                creationDate           startDate             endDate    value
# 177     2023-07-24 10:41:41 2023-07-23 10:41:00 2023-07-23 10:41:00  473.176
# 230     2023-08-23 09:54:44 2023-08-23 09:54:00 2023-08-23 09:54:00  236.588
# 234     2023-08-25 07:02:45 2023-08-25 07:02:00 2023-08-25 07:02:00  473.176
# 235     2023-08-25 07:02:55 2023-08-26 07:02:00 2023-08-26 07:02:00  473.176
# 247     2023-09-05 08:30:09 2023-09-05 08:30:00 2023-09-05 08:30:00  473.176
# ...                     ...                 ...                 ...      ...
# 2036992 2024-03-06 01:01:10 2024-03-06 01:00:08 2024-03-06 01:01:07  44.3289
# 2036993 2024-03-06 03:01:11 2024-03-06 03:00:09 2024-03-06 03:01:08  54.3759
# 2036994 2024-03-06 05:01:11 2024-03-06 05:00:09 2024-03-06 05:01:08    76.23
# 2036995 2024-03-06 07:01:22 2024-03-06 07:00:20 2024-03-06 07:01:20  45.6944
# 2036996 2024-03-06 09:39:13 2024-03-06 09:38:12 2024-03-06 09:39:11  10.3325
#
# [856985 rows x 6 columns]

# %%
records_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 856985 entries, 177 to 2036996
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   type          856985 non-null  object
#  1   unit          843298 non-null  object
#  2   creationDate  856985 non-null  datetime64[ns]
#  3   startDate     856985 non-null  datetime64[ns]
#  4   endDate       856985 non-null  datetime64[ns]
#  5   value         856985 non-null  object
# dtypes: datetime64[ns](3), object(3)
# memory usage: 45.8+ MB

# %%
records_df = records_df.reset_index()

# %%
classifiers = records_df.drop(records_df[records_df['value'] < '99999999.9999999'].index, axis = 0)
classifiers
# Out:
#           index                                        type unit  \
# 793917  1899798       HKCategoryTypeIdentifierSleepAnalysis  NaN
# 793918  1899799       HKCategoryTypeIdentifierSleepAnalysis  NaN
# 793919  1899800       HKCategoryTypeIdentifierSleepAnalysis  NaN
# 793920  1899801       HKCategoryTypeIdentifierSleepAnalysis  NaN
# 793921  1899802       HKCategoryTypeIdentifierSleepAnalysis  NaN
# ...         ...                                         ...  ...
# 807599  1921352  HKCategoryTypeIdentifierAudioExposureEvent  NaN
# 807600  1921353  HKCategoryTypeIdentifierAudioExposureEvent  NaN
# 807601  1921354  HKCategoryTypeIdentifierAudioExposureEvent  NaN
# 807602  1921355  HKCategoryTypeIdentifierAudioExposureEvent  NaN
# 807603  1921356  HKCategoryTypeIdentifierAudioExposureEvent  NaN
#
#               creationDate           startDate             endDate  \
# 793917 2023-07-24 05:30:00 2023-07-23 21:52:17 2023-07-23 21:53:47
# 793918 2023-07-24 05:30:00 2023-07-23 22:13:46 2023-07-23 22:13:59
# 793919 2023-07-24 05:30:00 2023-07-23 22:14:56 2023-07-23 22:58:00
# 793920 2023-07-24 07:05:22 2023-07-23 23:12:48 2023-07-23 23:40:48
# 793921 2023-07-24 07:05:22 2023-07-23 23:40:48 2023-07-24 00:06:18
# ...                    ...                 ...                 ...
# 807599 2024-01-21 11:51:53 2024-01-21 11:49:03 2024-01-21 11:51:53
# 807600 2024-02-09 10:46:59 2024-02-09 10:44:04 2024-02-09 10:46:59
# 807601 2024-02-12 15:42:33 2024-02-12 15:39:43 2024-02-12 15:42:33
# 807602 2024-02-13 08:30:05 2024-02-13 08:27:10 2024-02-13 08:30:05
# 807603 2024-02-20 11:13:37 2024-02-20 11:10:42 2024-02-20 11:13:37
#
#                                                     value
# 793917                  HKCategoryValueSleepAnalysisInBed
# 793918                  HKCategoryValueSleepAnalysisInBed
# 793919                  HKCategoryValueSleepAnalysisInBed
# 793920             HKCategoryValueSleepAnalysisAsleepCore
# 793921             HKCategoryValueSleepAnalysisAsleepDeep
# ...                                                   ...
# 807599  HKCategoryValueEnvironmentalAudioExposureEvent...
# 807600  HKCategoryValueEnvironmentalAudioExposureEvent...
# 807601  HKCategoryValueEnvironmentalAudioExposureEvent...
# 807602  HKCategoryValueEnvironmentalAudioExposureEvent...
# 807603  HKCategoryValueEnvironmentalAudioExposureEvent...
#
# [13687 rows x 7 columns]

# %%
numbers = records_df.drop(records_df[records_df['value'] > '99999999.9999999'].index, axis = 0)

# %% [markdown]
# Fantastic, so we have two dataframes, one with numeric classifiers and one with binomial classifiers. Let's go ahead and do some feature engineering on the `value` information.

# %%
classifier_scrubbed = classifiers
classifier_scrubbed['unit'] = classifiers['value']
classifier_scrubbed
# Out:
#           index                                        type  \
# 793917  1899798       HKCategoryTypeIdentifierSleepAnalysis
# 793918  1899799       HKCategoryTypeIdentifierSleepAnalysis
# 793919  1899800       HKCategoryTypeIdentifierSleepAnalysis
# 793920  1899801       HKCategoryTypeIdentifierSleepAnalysis
# 793921  1899802       HKCategoryTypeIdentifierSleepAnalysis
# ...         ...                                         ...
# 807599  1921352  HKCategoryTypeIdentifierAudioExposureEvent
# 807600  1921353  HKCategoryTypeIdentifierAudioExposureEvent
# 807601  1921354  HKCategoryTypeIdentifierAudioExposureEvent
# 807602  1921355  HKCategoryTypeIdentifierAudioExposureEvent
# 807603  1921356  HKCategoryTypeIdentifierAudioExposureEvent
#
#                                                      unit        creationDate  \
# 793917                  HKCategoryValueSleepAnalysisInBed 2023-07-24 05:30:00
# 793918                  HKCategoryValueSleepAnalysisInBed 2023-07-24 05:30:00
# 793919                  HKCategoryValueSleepAnalysisInBed 2023-07-24 05:30:00
# 793920             HKCategoryValueSleepAnalysisAsleepCore 2023-07-24 07:05:22
# 793921             HKCategoryValueSleepAnalysisAsleepDeep 2023-07-24 07:05:22
# ...                                                   ...                 ...
# 807599  HKCategoryValueEnvironmentalAudioExposureEvent... 2024-01-21 11:51:53
# 807600  HKCategoryValueEnvironmentalAudioExposureEvent... 2024-02-09 10:46:59
# 807601  HKCategoryValueEnvironmentalAudioExposureEvent... 2024-02-12 15:42:33
# 807602  HKCategoryValueEnvironmentalAudioExposureEvent... 2024-02-13 08:30:05
# 807603  HKCategoryValueEnvironmentalAudioExposureEvent... 2024-02-20 11:13:37
#
#                  startDate             endDate  \
# 793917 2023-07-23 21:52:17 2023-07-23 21:53:47
# 793918 2023-07-23 22:13:46 2023-07-23 22:13:59
# 793919 2023-07-23 22:14:56 2023-07-23 22:58:00
# 793920 2023-07-23 23:12:48 2023-07-23 23:40:48
# 793921 2023-07-23 23:40:48 2023-07-24 00:06:18
# ...                    ...                 ...
# 807599 2024-01-21 11:49:03 2024-01-21 11:51:53
# 807600 2024-02-09 10:44:04 2024-02-09 10:46:59
# 807601 2024-02-12 15:39:43 2024-02-12 15:42:33
# 807602 2024-02-13 08:27:10 2024-02-13 08:30:05
# 807603 2024-02-20 11:10:42 2024-02-20 11:13:37
#
#                                                     value
# 793917                  HKCategoryValueSleepAnalysisInBed
# 793918                  HKCategoryValueSleepAnalysisInBed
# 793919                  HKCategoryValueSleepAnalysisInBed
# 793920             HKCategoryValueSleepAnalysisAsleepCore
# 793921             HKCategoryValueSleepAnalysisAsleepDeep
# ...                                                   ...
# 807599  HKCategoryValueEnvironmentalAudioExposureEvent...
# 807600  HKCategoryValueEnvironmentalAudioExposureEvent...
# 807601  HKCategoryValueEnvironmentalAudioExposureEvent...
# 807602  HKCategoryValueEnvironmentalAudioExposureEvent...
# 807603  HKCategoryValueEnvironmentalAudioExposureEvent...
#
# [13687 rows x 7 columns]

# %%
classifier_scrubbed['value'] = 1
classifier_scrubbed
# Out:
#           index                                        type  \
# 793917  1899798       HKCategoryTypeIdentifierSleepAnalysis
# 793918  1899799       HKCategoryTypeIdentifierSleepAnalysis
# 793919  1899800       HKCategoryTypeIdentifierSleepAnalysis
# 793920  1899801       HKCategoryTypeIdentifierSleepAnalysis
# 793921  1899802       HKCategoryTypeIdentifierSleepAnalysis
# ...         ...                                         ...
# 807599  1921352  HKCategoryTypeIdentifierAudioExposureEvent
# 807600  1921353  HKCategoryTypeIdentifierAudioExposureEvent
# 807601  1921354  HKCategoryTypeIdentifierAudioExposureEvent
# 807602  1921355  HKCategoryTypeIdentifierAudioExposureEvent
# 807603  1921356  HKCategoryTypeIdentifierAudioExposureEvent
#
#                                                      unit        creationDate  \
# 793917                  HKCategoryValueSleepAnalysisInBed 2023-07-24 05:30:00
# 793918                  HKCategoryValueSleepAnalysisInBed 2023-07-24 05:30:00
# 793919                  HKCategoryValueSleepAnalysisInBed 2023-07-24 05:30:00
# 793920             HKCategoryValueSleepAnalysisAsleepCore 2023-07-24 07:05:22
# 793921             HKCategoryValueSleepAnalysisAsleepDeep 2023-07-24 07:05:22
# ...                                                   ...                 ...
# 807599  HKCategoryValueEnvironmentalAudioExposureEvent... 2024-01-21 11:51:53
# 807600  HKCategoryValueEnvironmentalAudioExposureEvent... 2024-02-09 10:46:59
# 807601  HKCategoryValueEnvironmentalAudioExposureEvent... 2024-02-12 15:42:33
# 807602  HKCategoryValueEnvironmentalAudioExposureEvent... 2024-02-13 08:30:05
# 807603  HKCategoryValueEnvironmentalAudioExposureEvent... 2024-02-20 11:13:37
#
#                  startDate             endDate  value
# 793917 2023-07-23 21:52:17 2023-07-23 21:53:47      1
# 793918 2023-07-23 22:13:46 2023-07-23 22:13:59      1
# 793919 2023-07-23 22:14:56 2023-07-23 22:58:00      1
# 793920 2023-07-23 23:12:48 2023-07-23 23:40:48      1
# 793921 2023-07-23 23:40:48 2023-07-24 00:06:18      1
# ...                    ...                 ...    ...
# 807599 2024-01-21 11:49:03 2024-01-21 11:51:53      1
# 807600 2024-02-09 10:44:04 2024-02-09 10:46:59      1
# 807601 2024-02-12 15:39:43 2024-02-12 15:42:33      1
# 807602 2024-02-13 08:27:10 2024-02-13 08:30:05      1
# 807603 2024-02-20 11:10:42 2024-02-20 11:13:37      1
#
# [13687 rows x 7 columns]

# %%
final_record = pd.concat([classifier_scrubbed, numbers])
final_records = final_record.drop('index', axis = 1)
final_records
# Out:
#                                                     type  \
# 793917             HKCategoryTypeIdentifierSleepAnalysis
# 793918             HKCategoryTypeIdentifierSleepAnalysis
# 793919             HKCategoryTypeIdentifierSleepAnalysis
# 793920             HKCategoryTypeIdentifierSleepAnalysis
# 793921             HKCategoryTypeIdentifierSleepAnalysis
# ...                                                  ...
# 856980  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 856981  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 856982  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 856983  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
# 856984  HKQuantityTypeIdentifierHeartRateVariabilitySDNN
#
#                                           unit        creationDate  \
# 793917       HKCategoryValueSleepAnalysisInBed 2023-07-24 05:30:00
# 793918       HKCategoryValueSleepAnalysisInBed 2023-07-24 05:30:00
# 793919       HKCategoryValueSleepAnalysisInBed 2023-07-24 05:30:00
# 793920  HKCategoryValueSleepAnalysisAsleepCore 2023-07-24 07:05:22
# 793921  HKCategoryValueSleepAnalysisAsleepDeep 2023-07-24 07:05:22
# ...                                        ...                 ...
# 856980                                      ms 2024-03-06 01:01:10
# 856981                                      ms 2024-03-06 03:01:11
# 856982                                      ms 2024-03-06 05:01:11
# 856983                                      ms 2024-03-06 07:01:22
# 856984                                      ms 2024-03-06 09:39:13
#
#                  startDate             endDate    value
# 793917 2023-07-23 21:52:17 2023-07-23 21:53:47        1
# 793918 2023-07-23 22:13:46 2023-07-23 22:13:59        1
# 793919 2023-07-23 22:14:56 2023-07-23 22:58:00        1
# 793920 2023-07-23 23:12:48 2023-07-23 23:40:48        1
# 793921 2023-07-23 23:40:48 2023-07-24 00:06:18        1
# ...                    ...                 ...      ...
# 856980 2024-03-06 01:00:08 2024-03-06 01:01:07  44.3289
# 856981 2024-03-06 03:00:09 2024-03-06 03:01:08  54.3759
# 856982 2024-03-06 05:00:09 2024-03-06 05:01:08    76.23
# 856983 2024-03-06 07:00:20 2024-03-06 07:01:20  45.6944
# 856984 2024-03-06 09:38:12 2024-03-06 09:39:11  10.3325
#
# [856985 rows x 6 columns]

# %%
import pickle
pickle.dump(final_records, open('final_records.p', 'wb'))

# %% [markdown]
# So, it appears there's no other information in the Sleep Analysis value that we need to worry about. So we can convert the

# %%
weight_data = final_records.to_csv('weight_data.csv', index = True)
